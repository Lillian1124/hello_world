# %%
import pandas as pd
from pandas import Series, DataFrame   # use these so often, this can be helpful

import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
###temperature picture
temp= pd.read_table('1104tem.txt', 
                comment='#',index_col=0)
tem_data = temp.iloc[:,:]
tem_data
# Out:
#         No     CK     Q1     Q2     Q3     Q4
# Day
# 20   29.33  31.20  31.00  30.47  31.83  31.60
# 40   27.70  29.87  29.80  29.13  30.37  30.03
# 60   27.77  30.07  28.93  29.00  29.63  29.30
# 80   28.87  31.37  30.67  30.23  30.90  30.87
# 100  27.47  29.47  28.40  28.33  29.33  29.07
# 120  26.70  28.50  27.83  27.53  28.10  27.90

# %%
h = tem_data.plot(legend=True,figsize=(10,6),fontsize=18) 
h.set_title('Soil Temperature',fontsize='xx-large')
h.set_xlabel('Days after covering the mulch/d',fontsize='xx-large')
h.set_ylabel('Soil Temperature/℃',fontsize='xx-large')
h.legend(fontsize='xx-large')

# %%
boxtem= tem_data.boxplot(figsize=(10,6),fontsize=18)

# %%
### degratation picture
dd= pd.read_table('dd.txt', 
                comment='#',index_col=0)
dd_data = dd.iloc[:,:]
dd_data
# Out:
#      CK  Q1  Q2  Q3  Q4
# Day
# 10    0   0   0   0   0
# 20    0   0   0   0   0
# 30    0   0   1   0   0
# 40    0   0   1   0   0
# 50    0   0   2   0   1
# 60    0   0   2   0   1
# 70    0   1   3   1   2
# 80    0   1   3   1   2
# 90    0   2   3   2   3
# 100   0   2   4   2   4
# 110   1   3   5   3   4
# 120   1   4   5   4   5

# %%
d = dd_data.plot(legend=True,figsize=(10,6),fontsize=20) 
d.set_title('Degratation Degree',fontsize='xx-large')
d.set_xlabel('Days after covering the mulch/d',fontsize='xx-large')
d.set_ylabel('Dagratation Degree',fontsize='xx-large')
d.legend(fontsize='xx-large')

# %%
### ANOVA analysis
tem_all= pd.read_table('temp20.txt')
tem_all
# Out:
#     Mulch3     Temp20     Temp60    Temp100
# 0       NO  29.474211  27.798978  28.150901
# 1       NO  30.010468  26.997082  26.684067
# 2       NO  29.423725  28.666110  27.302513
# 3       NO  29.039781  28.244946  27.211810
# 4       NO  29.048598  28.379464  28.110771
# 5       NO  29.381125  28.141853  28.782073
# 6       NO  29.123826  28.165485  28.763189
# 7       NO  29.202466  27.471917  26.973327
# 8       NO  29.040097  28.817538  27.231690
# 9       NO  28.720767  28.009212  27.592442
# 10      NO  28.977756  28.595198  26.621257
# 11      NO  29.552184  26.466817  27.630231
# 12      NO  28.680182  27.353605  26.677754
# 13      NO  29.062241  27.845513  26.851323
# 14      NO  29.602361  27.232720  27.594338
# 15      NO  30.586207  27.004323  27.677891
# 16      NO  29.486480  27.089806  27.730483
# 17      NO  29.071235  27.507513  27.587650
# 18      NO  29.750308  27.197432  28.629756
# 19      NO  28.700552  27.350509  28.625174
# ...

# %%
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
anova_result20 = anova_lm(ols('Temp20~Mulch3',tem_all).fit())
anova_result60 = anova_lm(ols('Temp60~Mulch3',tem_all).fit())
anova_result100 = anova_lm(ols('Temp100~Mulch3',tem_all).fit())

# %%
print(anova_result20)
print(anova_result60)
print(anova_result100)
# Out:
#              df     sum_sq    mean_sq          F        PR(>F)
# Mulch3      5.0  84.590363  16.918073  49.157786  6.762701e-27
# Residual  114.0  39.234075   0.344159        NaN           NaN
#              df     sum_sq    mean_sq          F        PR(>F)
# Mulch3      5.0  64.874074  12.974815  37.291325  1.699631e-22
# Residual  114.0  39.664154   0.347931        NaN           NaN
#              df     sum_sq   mean_sq          F        PR(>F)
# Mulch3      5.0  49.302040  9.860408  27.923636  2.238062e-18
# Residual  114.0  40.255736  0.353120        NaN           NaN

# %%
##$ multi Comp
#multiComp = M(df['StressReduction'], df['Treatment'])
#tukey=multiComp.tukeyhsd()
#summary=multiComp.tukeyhsd().summary()
#print(summary)

# %%
tem_60= pd.read_table('tem60.txt')
tem_60.head()
# Out:
#           No         CK         Q1         Q2         Q3         Q4
# 0  27.798978  29.769279  28.548176  28.619264  29.524749  29.944301
# 1  26.997082  30.839780  29.628179  28.415564  30.507975  29.858927
# 2  28.666110  30.535980  28.849525  28.309300  29.261133  29.503143
# 3  28.244946  30.497267  28.455191  28.923982  29.160786  29.997143
# 4  28.379464  29.663665  28.728325  28.909883  29.325236  28.412489

# %%
boxtem= tem_60.boxplot(figsize=(10,8),fontsize=20)
boxtem.set_title('Soil temperature of different treatment',fontsize='xx-large')
boxtem.set_xlabel('Treatment',fontsize='xx-large')
boxtem.set_ylabel('Soil temperature',fontsize='xx-large')
# Out:
# Text(0,0.5,'Soil temperature')

# %%
####yield
Y= pd.read_table('yield.txt')
Y
# Out:
#             No           CK           Q1           Q2           Q3  \
# 0  4657.760869  5313.779927  5168.672621  4770.315602  5532.993432
# 1  4963.903500  5337.073243  4929.518059  4771.681717  5413.812801
# 2  4707.630327  5388.898720  4977.048007  4712.718750  5588.802703
#
#             Q4
# 0  5273.693568
# 1  5294.591428
# 2  5162.903059

# %%
### ANOVA analysis
yield2= pd.read_table('yield2.txt')
yield2
# Out:
#    Mulch        Yield
# 0     No  4657.760869
# 1     No  4963.903500
# 2     No  4707.630327
# 3     No  4780.330000
# 4     CK  5313.779927
# 5     CK  5337.073243
# 6     CK  5388.898720
# 7     CK  5359.220000
# 8     Q1  5168.672621
# 9     Q1  4929.518059
# 10    Q1  4977.048007
# 11    Q1  5026.310000
# 12    Q2  4770.315602
# 13    Q2  4771.681717
# 14    Q2  4712.718750
# 15    Q2   475.980000
# 16    Q3  5532.993432
# 17    Q3  5413.812801
# 18    Q3  5588.802703
# 19    Q3  5511.900000
# 20    Q4  5273.693568
# 21    Q4  5294.591428
# 22    Q4  5162.903059
# 23    Q4  5243.320000

# %%
#yield_anova    = anova_lm(ols('yield~Mulch',yield2).fit())
#print(yield_anova)
anova_result60 = anova_lm(ols('Temp60~Mulch3',tem_all).fit())
yield_anova = anova_lm(ols('yield~Mulch',yield2).fit())
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# ~\Anaconda3\anaconda\lib\site-packages\patsy\compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# ~\Anaconda3\anaconda\lib\site-packages\patsy\eval.py in eval(self, expr, source_name, inner_namespace)
#     163         """
# --> 164         code = compile(expr, source_name, "eval", self.flags, False)
#     165         return eval(code, {}, VarLookupDict([inner_namespace]
#
# SyntaxError: unexpected EOF while parsing (<string>, line 1)
#
# The above exception was the direct cause of the following exception:
#
# PatsyError                                Traceback (most recent call last)
# <ipython-input-145-8d726a3f5364> in <module>()
#       2 #print(yield_anova)
# ...

# %%
yield_anova = anova_lm

# %%
xlabel = ('No','CK','Q1','Q2','Q3','Q4')
fig, axes = plt.subplots(sharey=True)
yield_averages = Y.mean()
index = np.arange(len(yield_averages))

_ = axes.bar(index, yield_averages)
_= axes.set_xlabel('Malch',fontsize='x-large')
_= axes.set_ylabel('Yield/(kg/hm2)',fontsize='x-large')
_= axes.set_xticks(range(len(yield_averages)))
labels = axes.set_xticklabels(xlabel, fontsize='x-large')
_=axes.tick_params(labelsize='large')
