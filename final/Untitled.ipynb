# %%
import pandas as pd
from pandas import Series, DataFrame   # use these so often, this can be helpful

import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
degratation= pd.read_table('pre.txt', 
                comment='#',index_col=1)

#print(degratation)
degratation_data = degratation.iloc[:,:]
degratation_data
#plt.plot(degratation.DD,'o',label = degratation.Mulch)
#plt.plot(degratation.Day,degratation.DD,data=degratation.Mulch)
#cd_dd = degratation[degratation.Mulch == 'CK']
#q1_dd=degratation[degratation.Mulch == 'Q1']
#cd_dd.head()
#plt.plot(cd_dd.Day,cd_dd.DD,label='CK')
#plt.plot(q1_dd.Day,q1_dd.DD,label='Q1')
# Out:
#        Day  DD
# Mulch
# CK      10   0
# CK      20   0
# CK      30   0
# CK      40   0
# CK      50   0
# CK      60   0
# CK      70   0
# CK      80   0
# CK      90   0
# CK     100   0
# CK     110   1
# CK     120   1
# Q1      10   0
# Q1      20   0
# Q1      30   0
# Q1      40   0
# Q1      50   0
# Q1      60   0
# Q1      70   1
# Q1      80   1
# Q1      90   2
# Q1     100   2
# Q1     110   3
# Q1     120   4
# Q2      10   0
# Q2      20   0
# Q2      30   1
# Q2      40   1
# Q2      50   2
# Q2      60   2
# Q2      70   3
# Q2      80   3
# Q2      90   3
# Q2     100   4
# Q2     110   5
# Q2     120   5
# Q3      10   0
# Q3      20   0
# Q3      30   0
# Q3      40   0
# Q3      50   0
# Q3      60   0
# Q3      70   1
# Q3      80   1
# Q3      90   2
# Q3     100   2
# Q3     110   3
# Q3     120   4
# Q4      10   0
# Q4      20   0
# Q4      30   0
# Q4      40   0
# Q4      50   1
# Q4      60   1
# Q4      70   2
# Q4      80   2
# Q4      90   3
# Q4     100   4
# Q4     110   4
# Q4     120   5

# %%
picture = degratation_data.plot(
    kind='line',
    title='data', 
)

# %%
print(degratation.columns)
print(degratation.index)
# Out:
# Index(['Day', 'Mulch', 'DD'], dtype='object')
# RangeIndex(start=0, stop=60, step=1)
